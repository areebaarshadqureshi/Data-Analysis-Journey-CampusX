# %%
# !pip install pandas-profiling
# Out:
# Requirement already satisfied: pandas-profiling in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (3.2.0)
# Requirement already satisfied: joblib~=1.1.0 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from pandas-profiling) (1.1.1)
# Requirement already satisfied: scipy>=1.4.1 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from pandas-profiling) (1.14.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from pandas-profiling) (2.2.3)
# Requirement already satisfied: matplotlib>=3.2.0 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from pandas-profiling) (3.9.2)
# Requirement already satisfied: pydantic>=1.8.1 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from pandas-profiling) (2.10.6)
# Requirement already satisfied: PyYAML>=5.0.0 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from pandas-profiling) (6.0.2)
# Requirement already satisfied: jinja2>=2.11.1 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from pandas-profiling) (3.1.4)
# Requirement already satisfied: markupsafe~=2.1.1 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from pandas-profiling) (2.1.5)
# Requirement already satisfied: visions==0.7.4 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (0.7.4)
# Requirement already satisfied: numpy>=1.16.0 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from pandas-profiling) (1.26.4)
# Requirement already satisfied: htmlmin>=0.1.12 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from pandas-profiling) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from pandas-profiling) (0.5.2)
# Requirement already satisfied: phik>=0.11.1 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from pandas-profiling) (0.12.5)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from pandas-profiling) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from pandas-profiling) (2.32.3)
# Requirement already satisfied: tqdm>=4.48.2 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from pandas-profiling) (4.67.3)
# Requirement already satisfied: seaborn>=0.10.1 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from pandas-profiling) (0.13.2)
# Requirement already satisfied: multimethod>=1.4 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from pandas-profiling) (2.0.2)
# Requirement already satisfied: attrs>=19.3.0 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (24.2.0)
# Requirement already satisfied: networkx>=2.4 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (3.4.2)
# Requirement already satisfied: imagehash in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (4.3.2)
# Requirement already satisfied: Pillow in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (11.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from matplotlib>=3.2.0->pandas-profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from pydantic>=1.8.1->pandas-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from pydantic>=1.8.1->pandas-profiling) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from pydantic>=1.8.1->pandas-profiling) (4.12.2)
# Requirement already satisfied: six>=1.5 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from requests>=2.24.0->pandas-profiling) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from requests>=2.24.0->pandas-profiling) (2026.1.4)
# Requirement already satisfied: colorama in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from tqdm>=4.48.2->pandas-profiling) (0.4.6)
# Requirement already satisfied: PyWavelets in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.9.0)

# %%
import pandas as pd
df=pd.read_csv('C:\\Users\QC\MachineLearining_implementation/train.csv')

# %%
pip install ydata-profiling
# Out:
# Requirement already satisfied: ydata-profiling in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (4.18.1)
# Requirement already satisfied: scipy<1.17,>=1.8 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from ydata-profiling) (1.14.1)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from ydata-profiling) (2.2.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from ydata-profiling) (3.9.2)
# Requirement already satisfied: pydantic<3,>=2 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from ydata-profiling) (2.10.6)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from ydata-profiling) (1.26.4)
# Requirement already satisfied: minify-html>=0.15.0 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.66.3 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from ydata-profiling) (4.67.3)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from ydata-profiling) (0.14.6)
# Requirement already satisfied: typeguard<5,>=4 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from ydata-profiling) (4.4.4)
# Requirement already satisfied: imagehash==4.3.2 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from ydata-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from ydata-profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from imagehash==4.3.2->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from imagehash==4.3.2->ydata-profiling) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2024.2)
# Requirement already satisfied: joblib>=0.14.1 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from pydantic<3,>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from pydantic<3,>=2->ydata-profiling) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2026.1.4)
# Requirement already satisfied: patsy>=0.5.6 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.2)
# Requirement already satisfied: colorama in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (24.2.0)
# Requirement already satisfied: networkx>=2.4 in C:\Users\QC\AppData\Roaming\Python\Python311\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.4.2)
# Requirement already satisfied: puremagic in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (1.30)
# Requirement already satisfied: six>=1.5 in C:\Users\QC\.conda\envs\ds_env\Lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ydata_profiling import ProfileReport

# %%
profile = ProfileReport(df)
profile.to_file("output.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
#  17%|█▋        | 2/12 [00:01<00:05,  1.86it/s]
#  33%|███▎      | 4/12 [00:01<00:02,  3.43it/s]
# 100%|██████████| 12/12 [00:01<00:00,  7.67it/s][A
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
